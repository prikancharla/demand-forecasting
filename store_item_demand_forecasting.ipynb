# %% [markdown]
# <a href="https://colab.research.google.com/github/prikancharla/demand-forecasting/blob/main/store_item_demand_forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
